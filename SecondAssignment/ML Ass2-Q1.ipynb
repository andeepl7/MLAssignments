# %%
# Question 1.1

#1. In this situation, the learner is overfitting. 
#Overfitting happens when a model learns the training data too well, capturing noise instead of the main patterns. 
#This leads to poor performance on new, unseen data. 
#It's important to balance the model's performance on training data and its ability to generalize.
#For example, consider a dataset of children's ages and heights. 
#A good model should capture the overall trend that children grow taller with age. 
#An overfitted model, however, learns the random variations in the data too, 
#causing inaccurate predictions for new data points. 
#A well-balanced model focuses on the main trend and performs better on new data.|

# %%
# Question 1.2

#When handling 1000 examples, the size-1 approach mandates the use of a loop, 
#incurring additional overhead costs. 
#In contrast, the size-1000 approach merely necessitates a single matrix multiplication operation.
#Employing the size-1000 technique leverages the benefits of matrix-matrix multiplication, 
#which boasts highly optimized implementations, such as enhanced cache efficiency.

# %%
# Question 1.3

# %%
from IPython import display
import numpy as np
display.Image("/Users/kotro/Desktop/Q3.png")

# %%
#The gradient descent update adjusts the model's parameters to minimize the cost function. 
#In the plot,we notice a move from the higher cost meaning the inner circles, to lower cost meaning the outer circles. 
#We draw an arrow from the × on the C=2 curve towards the C=1 curve, representing the update step.

# %%
# Questions 1.4

# %%
display.Image("/Users/kotro/Desktop/Q4.png")

# %%
#We have two training cases with targets:
#x = (1, -1), t = 1
#x = (-1, -1), t = 0
#And two decision boundaries:
#-w1 - w2 - 1 = 0
#w1 - w2 - 1 = 0
#For case 1 (x = (1, -1), t = 1), we need the perceptron output >= 0.5. 
#Subsequently we have to shade the region above the line -w1 - w2 - 1 = 0.
#For case 2 (x = (-1, -1), t = 0), we need the perceptron output < 0.5. 
#Subsequently we have to shade the regionbelow the line w1 - w2 - 1 = 0.
